# %% [markdown]
# 1 - Escribir una función que pida un número entero entre 1 y 10 y guarde en un fichero con el nombre `tabla-n.txt` la tabla de multiplicar de ese número, done `n` es el número introducido.

# %% [markdown]
# Solución 1

# %%
n = int(input('Introduce un número entero entre 1 y 10: '))

#crea un nombre de archivo basado en el número ingresado por el usuario
    #'tabla-' se concatena al inicio del nombre del archivo.
    #str(n) convierte el número entero n a una cadena de texto.
    #'.txt' se agrega al final del nombre del archivo para indicar que es un archivo de texto.
nombre_fichero = 'tabla-' + str(n) + '.txt' #El resultado se almacena en la variable nombre_fichero.

#
f = open(nombre_fichero, 'w') #abre el archivo especificado por nombre_fichero en modo de escritura.

#El bucle for recorre los números del 1 al 10.
for i in range(1, 11): 
    #Dentro del bucle, escribe una línea en el archivo para cada valor de i
        #str(n): Convierte el número n a una cadena de texto.
        #' x ': Concatena el símbolo "x" entre n e i
        # str(i): Convierte el número i a una cadena de texto.
        #str(n * i): Convierte el resultado de la multiplicación de n por i a una cadena de texto.
    f.write(str(n) + ' x ' + str(i) + ' = ' + str(n * i) + '\n')
#f.close(), cierra el archivo abierto por f
f.close()

# %% [markdown]
# Solución 2

# %%
n = int(input('Introduce un número entero entre 1 y 10: '))
#

nombre_fichero = 'tabla-' + str(n) + '.txt'
#
with open(nombre_fichero, 'w') as f:
    for i in range(1, 11):
        #f.write() es un método utilizado para escribir contenido en el archivo que abrimos (f).
        f.write(str(n) + ' x ' + str(i) + ' = ' + str(n * i) + '\n')

# %% [markdown]
# 2 - Escribir una función que pida un número entero entre 1 y 10, lea el fichero `tabla-n.txt` con la tabla de multiplicar de ese número, donde `n` es el número introducido, y la muestre por pantalla. Si el fichero no existe debe mostrar un mensaje por pantalla informando de ello.

# %% [markdown]
# Solución 1

# %% [markdown]
#  > Intenta abrir un archivo de texto llamado "tabla-N.txt" (donde N es un número entre 1 y 10) e imprimir la línea M del archivo (donde M es otro número entre 1 y 10). Si el archivo no existe, muestra un mensaje de error.

# %%
#pide al usuario que ingrese un número entero entre 1 y 10.
n = int(input('Introduce un número entero entre 1 y 10: ')) 

nombre_fichero = 'tabla-' + str(n) + '.txt' #Crear nombre de archivo con extensión txt

# El bloque try-except se utiliza para manejar posibles errores al abrir el archivo:
try: 
    f = open(nombre_fichero, 'r') #intenta abrir el archivo especificado por nombre_fichero en modo lectura ('r').
except FileNotFoundError: #Si se produce la excepción, se imprime un mensaje indicando que el archivo no existe
    print('No existe el fichero con la tabla del', n)
    
else: #Este bloque se ejecuta si el código dentro del bloque try se ejecuta sin generar una excepción.
    print(f.read()) #Esta línea lee todo el contenido del archivo abierto y lo imprime en la consola.
    f.close() #Esta línea lee todo el contenido del archivo abierto y lo imprime en la consola.
# Out:
# No existe el fichero con la tabla del 11

# %% [markdown]
# Solución 2

# %%
n = int(input('Introduce un número entero entre 1 y 10: '))
nombre_fichero = 'tabla-' + str(n) + '.txt'
try: 
    with open(nombre_fichero, 'r') as f:
        print(f.read())
except FileNotFoundError:
    print('No existe el fichero con la tabla del', n)

# %% [markdown]
# 3 - Escribir una función que pida dos números n y m entre 1 y 10, lea el fichero `tabla-n.txt` con la tabla de multiplicar de ese número, y muestre por pantalla la línea `m` del fichero. Si el fichero no existe debe mostrar un mensaje por pantalla informando de ello.

# %% [markdown]
# > Intenta abrir un archivo de texto llamado "tabla-N.txt" (donde N es un número entre 1 y 10) e imprimir la línea M del archivo (donde M es otro número entre 1 y 10). Si el archivo no existe, muestra un mensaje de error.

# %%
n = int(input('Introduce un número entero entre 1 y 10: '))
m = int(input('Introduce otro número entero entre 1 y 10: '))
nombre_fichero = 'tabla-' + str(n) + '.txt'

#try se utiliza para incluir código que podría generar una excepción. Si se produce una excepción dentro del bloque try, se ejecuta el código siguiente al bloque except
try: 
    with open(nombre_fichero, 'r') as f:
        lineas = f.readlines()  #lee todas las líneas del archivo f y las almacena como una lista en la variable lineas.
    print(lineas[m - 1]) #intenta imprimir la línea M del archivo, accede a la lista lineas utilizando el índice m - 1 

# Manejar la excepción de archivo no encontrado
except FileNotFoundError:
    print('No existe el fichero con la tabla del ', n)

# %% [markdown]
# 4 - Escribir un programa que acceda a un fichero de internet mediante su url y muestre por pantalla el número de palabras que contiene.

# %% [markdown]
# Solución 1

# %%
def contar_palabras(url):
    '''
    Función que recibe recibe la url de un fichero de texto y devuelve el número de palabras que contiene.
    Parámetros:
        url: Es una cadena con la url del fichero de texto.
    Devuelve:
        El número de palabras que contiene el fichero de texto dado por la url.
    '''
    from urllib import request #realizar solicitudes HTTP.
    from urllib.error import URLError #Maneja errores de red
    
    #bloque try se utiliza para intentar abrir la URL especificada
    try: 
        f = request.urlopen(url) #intenta abrir la URL especificada por url utilizando la función urlopen del módulo request
                                 #Si la URL es válida y el archivo existe, la variable f contendrá un objeto que representa el archivo abierto 
    
    #se ejecuta si se produce una excepción URLError al intentar abrir la URL
    except URLError: 
        return('¡La url ' + url + ' no existe!') # mensaje de error indicando que la URL no existe
    
    #Este bloque se ejecuta si el código dentro del bloque try se ejecuta sin generar una excepción
    else:
        contenido = f.read() # lee todo el contenido del archivo abierto y lo almacena en la variable contenido
        return len(contenido.split()) #divide el contenido del archivo en palabras usando el método split() de la cadena contenido. Luego, devuelve la longitud de la lista resultante, que representa el número de palabras en el archivo

print(contar_palabras('https://www.gutenberg.org/files/2000/2000-0.txt')) # llama a la función contar_palabras con la URL de un libro electrónico
print(contar_palabras('https://no-existe.txt')) #llama a la función contar_palabras con una URL no válida y muestra el mensaje de error
# Out:
# 389719
# ¡La url https://no-existe.txt no existe!

# %% [markdown]
# Solucion 2

# %%
def contar_palabras(url):
    '''
    Función que recibe recibe la url de un fichero de texto y devuelve el número de palabras que contiene.
    Parámetros:
        url: Es una cadena con la url del fichero de texto.
    Devuelve:
        El número de palabras que contiene el fichero de texto daro por la url.
    '''
    from urllib import request
    from urllib.error import URLError
    try:
        with request.urlopen(url) as f:
            contenido = f.read()
    except URLError:
        return('¡La url ' + url + ' no existe!')
    else:
        return len(contenido.split())

print(contar_palabras('https://www.gutenberg.org/files/2000/2000-0.txt'))
print(contar_palabras('https://no-existe.txt'))
# Out:
# 389719
# ¡La url https://no-existe.txt no existe!

# %% [markdown]
# 5 - Escribir un programa para gestionar un listín telefónico con los nombres y los teléfonos de los clientes de una empresa. El programa incorporar funciones crear el fichero con el listín si no existe, para consultar el teléfono de un cliente, añadir el teléfono de un nuevo cliente y eliminar el teléfono de un cliente. El listín debe estar guardado en el fichero de texto listin.txt donde el nombre del cliente y su teléfono deben aparecer separados por comas y cada cliente en una línea distinta.

# %% [markdown]
# > Proporciona un conjunto de funciones para la gestión de un listín telefónico almacenado en un archivo de texto. Las funciones permiten consultar, añadir, eliminar y crear el listín telefónico.

# %%
#función devuelve el teléfono de un cliente específico del listín telefónico almacenado en el archivo file
def get_phone(file, client): # 
    '''
    Función que devuelve el teléfono de un cliente de un fichero dado.
    Parámetros:
        file: Es un fichero con los nombres y teléfonos de clientes.
        client: Es una cadena con el nombre del cliente.
    Devuelve:
        El teléfono del cliente guardado en el fichero o un mensaje de error si el teléfono o el fichero no existe.
    '''
    #
    try: 
        f = open(file, 'r')
    except FileNotFoundError:
        return('¡El fichero ' + file + ' no existe!\n')
    else:
        directory = f.readlines()
        f.close()
        directory = dict([tuple(line.split(',')) for line in directory])
        if client in directory:
            return directory[client]
        else:
            return('¡El cliente ' + client + ' no existe!\n')


# función añade el teléfono de un nuevo cliente al listín telefónico almacenado en el archivo file
def add_phone(file, client, telf):
    '''
    Función que añade el teléfono de un cliente de un fichero dado.
    Parámetros:
        file: Es un fichero con los nombres y teléfonos de clientes.
        client: Es una cadena con el nombre del cliente.
        telf: Es una cadena con el teléfono del cliente.
    Devuelve:
        Un mesaje informando sobre si el teléfono se ha añadido o ha habido algún problema.
    '''
    try: 
        f = open(file, 'a')
    except FileNotFoundError:
        return('¡El fichero ' + file + ' no existe!\n')
    else:
        f.write(client + ',' + telf + '\n')
        f.close()
        return('El teléfono se ha añadido.\n')

#función elimina el teléfono de un cliente específico del listín telefónico almacenado en el archivo file
def remove_phone(file, client):
    '''
    Función que elimina el teléfono de un cliente de un fichero dado.
    Parámetros:
        file: Es un fichero con los nombres y teléfonos de clientes.
        client: Es una cadena con el nombre del cliente.
    Devuelve:
        Un mesaje informando sobre si el teléfono se ha borrado o ha habido algún problema.
    '''
    try: 
        f = open(file, 'r')
    except FileNotFoundError:
        return('¡El fichero ' + file + ' no existe!\n')
    else:
        directory = f.readlines()
        f.close()
        directory = dict([tuple(line.split(',')) for line in directory])
        if client in directory:
            del directory[client]
            f = open(file, 'w')
            for name, telf in directory.items():
                f.write(name + ',' + telf)
            f.close()
            return ('¡El cliente se ha borrado!\n')
        else:
            return('¡El cliente ' + client + ' no existe!\n')


#función crea un nuevo archivo vacío con el nombre file para almacenar un listín telefónico.
def create_directory(file):
    '''
    Función que crea un fichero vacío para guardar un listín telefónico.
    Parámetros:
        file: Es un fichero.
    Devuelve:
        Un mesaje informando sobre si el fichero se ha creado correctamente o no.
    '''
    import os #módulo proporciona funciones para trabajar con el sistema operativo
    if os.path.isfile(file):  #utiliza la función isfile() del módulo os para verificar si el archivo especificado por la variable file existe
        
        #muestra un mensaje al usuario indicando que el archivo ya existe y le pregunta si desea vaciarlo.
        answer = input('El fichero ' + file + ' ya existe. ¿Desea vaciarlo (S/N)? ')
        if answer == 'N': 
            return 'No se ha creado el fichero porque ya existe.\n'
    #abre el archivo especificado por file en modo de escritura ('w').
    f = open(file, 'w')
    f.close()
    return 'Se ha creado el fichero.\n'
     

#función presenta un menú al usuario con las opciones disponibles para la gestión del listín telefónico y devuelve la opción seleccionada
def menu():
    '''
    Función que presenta un menú con las operaciones disponibles sobre un listín telefónico y devuelve la opción seleccionada por el usuario.
    Devuelve:
        La opción seleccionada por el usuario.
    '''
    print('Gesión del listín telefónico')
    print('============================')
    print('1 - Consultar un teléfono')
    print('2 - Añadir un teléfono')
    print('3 - Eliminar un teléfono')
    print('4 - Crear el listín')
    print('0 - Terminar')
    option = input('Introduzca el número de la opción deseada: ')
    return option

#función se encarga de controlar el flujo de la aplicación, presentando el menú al usuario, recibiendo su elección y ejecutando las funciones correspondientes para realizar las operaciones deseadas.
def directory():
    '''
    Función que lanza la aplicación para la gestión del listín telefónico.
    '''
    file = 'listin.txt' # define una variable file que almacena el nombre del archivo del listín telefónico
    
    # inicia un bucle infinito que se ejecuta hasta que el usuario decide salir de la aplicación
    while True:
        option = menu() #lama a la función menu() para mostrar el menú al usuario y obtener la opción seleccionada.
        
        if option == '1': #Consultar un teléfono
            name = input('Introduce el nombre del cliente: ')
            print(get_phone(file, name)) #llama a la función get_phone() para obtener el teléfono del cliente especificado y lo imprime
        
        elif option == '2': #Añadir un teléfono
            name = input('Introduce el nombre del cliente: ')
            telf = input('Introduce el teléfono del cliente: ')
            print(add_phone(file, name, telf))
            
        elif option == '3':#Eliminar un teléfono
            name = input('Introduce el nombre del cliente: ')
            print(remove_phone(file, name))
            
        elif option == '4': #Crear el listín
            print(create_directory(file))
        else:
            break
    return

directory()
# Out:
# Gesión del listín telefónico
# ============================
# 1 - Consultar un teléfono
# 2 - Añadir un teléfono
# 3 - Eliminar un teléfono
# 4 - Crear el listín
# 0 - Terminar
# El teléfono se ha añadido.
#
# Gesión del listín telefónico
# ============================
# 1 - Consultar un teléfono
# 2 - Añadir un teléfono
# 3 - Eliminar un teléfono
# 4 - Crear el listín
# 0 - Terminar
# No se ha creado el fichero porque ya existe.
#
# Gesión del listín telefónico
# ============================
# 1 - Consultar un teléfono
# 2 - Añadir un teléfono
# 3 - Eliminar un teléfono
# 4 - Crear el listín
# 0 - Terminar
# ¡El cliente se ha borrado!
#
# Gesión del listín telefónico
# ============================
# 1 - Consultar un teléfono
# 2 - Añadir un teléfono
# 3 - Eliminar un teléfono
# 4 - Crear el listín
# 0 - Terminar

# %% [markdown]
# 6 - El fichero [cotizacion.csv](https://aprendeconalf.es/docencia/python/ejercicios/soluciones/ficheros/cotizacion.csv) contiene las cotizaciones de las empresas del IBEX35 con las siguientes columnas: Nombre (nombre de la empresa), Final (precio de la acción al cierre de bolsa), Máximo (precio máximo de la acción durante la jornada), Mínimo (precio mínimo de la acción durante la jornada), Volumen (Volumen al cierre de bolsa), Efectivo (capitalización al cierre en miles de euros).
#
# - Construir una función reciba el fichero de cotizaciones y devuelva un diccionario con los datos del fichero por columnas.
#
# - Construir una función que reciba el diccionario devuelto por la función anterior y cree un fichero en formato csv con el mínimo, el máximo y la media de dada columna.

# %%
def limpiar(cifra):
    """
    Función que elimina los puntos de separación de miles y cambia las comas de separación de decimales por puntos.
    Parámetros:
        - cifra: Es una cadena con una cifra
    Devuelve:
        Un real con la cifra de la cadena después de eliminar el separador de miles y cambiar el separador de decimales por punto.
    
    CSV    
    Apellidos;Nombre;Asistencia;Parcial1;Parcial2;Ordinario1;Ordinario2;Practicas;OrdinarioPracticas
    Anido Bonet;David;90%;5,5;2,75;;5;;
    Bueno Cerdeira;Patricia;95%;9,5;9;;;6,25;
    
    """
    cifra = cifra.replace('.', '') # elimina puntos adicionales que puedan estar presentes en la representación de la cifra
    cifra = cifra.replace(',','.') #reemplaza todas las ocurrencias de coma (,) en la cadena cifra por un punto (.)
    return float(cifra) #convierte la cadena cifra limpia en un número flotante (float).

#función procesa un archivo CSV de cotizaciones
# devuelve un diccionario que contiene las cotizaciones limpias y organizadas por nombre y fecha.
def preprocesado(ruta):
    """
    Función que preprocesa los datos contenidos en un fichero con formato csv y devuelve un diccionario con los nombres de las columnas como claves y las listas de valores asociados a ellas.
    Parámetros:
        - ruta: Es una cadena con la ruta del fichero.
    Devuelve:
        Un diccionario con pares formados por los nombres de las columnas y las listas de valores en las columnas.
    """
    
    #bloque try-except para manejar posibles errores de apertura del archivo CSV.
    #Si el archivo se abre correctamente, se procede a procesar sus datos 
    #Si el archivo no se encuentra, se imprime un mensaje de error y se devuelve None
    try:
        # Abrimos el fichero en modo lectura
        with open(ruta, 'r') as f:
            # Leemos el fichero por líneas en una lista
            lineas = f.read().split('\n') 
    except FileNotFoundError:
        print('El fichero no existe.')
        return
    
    #Extracción de las claves (nombres de las columnas)
    #se extrae la primera línea de la lista lineas y se almacena en la variable primera_linea.
    #Se divide la primera línea en una lista de claves utilizando el método split(';')
    claves = lineas.pop(0).split(";")
    
    #Inicialización del diccionario para almacenar los datos
    cotizaciones = {}
    
    for i in claves:
        cotizaciones[i] = []
    
    for linea in lineas:
        
        campos = linea.split(';')
        
        cotizaciones[claves[0]].append(campos[0])
       
        for i in range(1, len(campos)):
            cotizaciones[claves[i]].append(limpiar(campos[i]))
    return cotizaciones


def resumen_cotizacion(cotizaciones, ruta):
    """
    Función que recibe un diccionario con los valores de cotización y crear un fichero con un resumen con el mínimo, el máximo y la media.
    Parámetros:
        - cotizaciones: Es un diccionario con pares cuyas claves son los nombres de la variables medidas y cuyos valores son las listas de valores de cada variable.
        - ruta: Es una cadena con la ruta del fichero.
    """
    
    del(cotizaciones['Nombre'])
    
    contenido = ""
    
    contenido += 'Nombre'
   
    for i in cotizaciones:
        contenido += ";" + i
    
    contenido += '\nMínimo'
    for i in cotizaciones.values():
        contenido += ';' + str(min(i))
    
    contenido += '\nMáximo'
    for i in cotizaciones.values():
        contenido += ';' + str(max(i))
    
    contenido += '\nMedia'
    for i in cotizaciones.values():
        contenido += ';' + str(sum(i)/len(i))
    
    with open(ruta, 'w') as f:
        
        f.write(contenido)
    return



cotizaciones = preprocesado('cotizacion.csv')
print(cotizaciones)
resumen_cotizacion(cotizaciones, 'resumen-cotizacion.csv')

# %% [markdown]
# 7 - El fichero [calificaciones.csv](https://aprendeconalf.es/docencia/python/ejercicios/soluciones/ficheros/calificaciones.csv) contiene las calificaciones de un curso. Durante el curso se realizaron dos exámenes parciales de teoría y un examen de prácticas. Los alumnos que tuvieron menos de 4 en alguno de estos exámenes pudieron repetirlo en la al final del curso (convocatoria ordinaria). Escribir un programa que contenga las siguientes funciones:
#
# Una función que reciba el fichero de calificaciones y devuelva una lista de diccionarios, donde cada diccionario contiene la información de los exámenes y la asistencia de un alumno. La lista tiene que estar ordenada por apellidos.
#
# Una función que reciba una lista de diccionarios como la que devuelve la función anterior y añada a cada diccionario un nuevo par con la nota final del curso. El peso de cada parcial de teoría en la nota final es de un 30% mientras que el peso del examen de prácticas es de un 40%.
#
# Una función que reciba una lista de diccionarios como la que devuelve la función anterior y devuelva dos listas, una con los alumnos aprobados y otra con los alumnos suspensos. Para aprobar el curso, la asistencia tiene que ser mayor o igual que el 75%, la nota de los exámenes parciales y de prácticas mayor o igual que 4 y la nota final mayor o igual que 5.

# %% [markdown]
# > Este código proporciona cuatro funciones para el procesamiento y análisis de datos de calificaciones de alumnos:

# %%
def nota(cifra):
    '''Función que elimina cambia las comas de separación de decimales por puntos de una cifra y la convierte en un real.
    Parámetros:
        - cifra: Es una cadena con una cifra.
    Devuelve:
        Un real con la cifra de la cadena después de cambiar el separador de decimales por punto.
    '''
    cifra = cifra.replace(',','.')
    return float(cifra) 

def calificaciones(ruta):
    '''Función que preprocesa los datos contenidos en un fichero con formato csv y devuelve una lista de diccionarios donde las claves de los diccionarios son los datos de la primera fila y los valores los datos de cada línea del fichero.
    
    Parámetros:
        - ruta: Es una cadena con la ruta del fichero.
    Devuelve:
        Una lista de diccionarios donde cada diccionario contiene los datos de una linea del fichero (a excepción de la primera línea), usando como claves los datos de la primera línea.
    '''
    try:
        # Abrimos el fichero en modo lectura
        f = open(ruta, 'r')
    except FileNotFoundError:
        print('El fichero no existe.')
        return
    
    lineas = f.readlines()
    
    f.close()
    
    #lineas[0] accede a la primera línea del archivo CSV (almacenada en la lista lineas
    #[:-1] elimina el último carácter de la primera línea (asumiendo que es un salto de línea).
    #.split(";") divide la cadena de texto en una lista de elementos
    #La variable claves almacena la lista de nombres de columnas extraídos de la primera línea del archivo CSV
    claves = lineas[0][:-1].split(";") 
    
    calificaciones = []
    
    
    #El bucle for i in lineas[1:]: recorre todas las líneas del archivo CSV, 
    #excepto la primera línea (que ya se ha utilizado para extraer los nombres de las columnas).
    for i in lineas[1:]:
       
        valores = i[:-1].split(";") #i[:-1] elimina el último carácter de la línea actual (asumiendo que es un salto de línea).
        
        alumno = {}
        
        for j in range(len(valores)):
            #añade un nuevo par clave-valor al diccionario alumno. 
            #La clave es el nombre de la columna correspondiente (obtenido de la lista claves) y el 
            #valor es el dato correspondiente extraído de la lista valore
            alumno[claves[j]] = valores[j]
        
        calificaciones.append(alumno)
    return calificaciones

def añadir_nota_final(calificaciones):
    '''Función que recibe una lista de diccionarios con las calificaciones de cada alumno en un curso, calcula la nota final del curso de cada alumno y la añade al diccionario del alumno.

    Parámetros:
        - calificaciones: Es una lista de diccionarios donde cada diccionario contiene los datos de un alumno (nombre, asistencia y notas de exámenes del curso).
    Devuelve:
        La lista de las calificaciones de los alumnos tras añadir a cada alumno de la lista su nota final del curso.
    '''

    def nota_final(alumno):
        '''Función que calcula la nota final del curso de un alumno.

        Parámetros:
            - alumno: Es un diccionario con las notas del alumno.
        Devuelve:
            El diccionario con los datos del alumno tras añadirle un nuevo par con la nota final del curso.
        '''
        if alumno['Ordinario1']: #Si el alumno se ha presentado al examen de repesca del primer parcial tomamos esa nota como la nota del primer parcial
            parcial1 = nota(alumno['Ordinario1'])
        elif alumno['Parcial1']:
            parcial1 = nota(alumno['Parcial1'])
        else: # No se ha presentado al primer parcial ni a la repesca en el ordinario
            parcial1 = 0
        if alumno['Ordinario2']: #Si el alumno se ha presentado al examen de repesca del segundo parcial tomamos esa nota como la nota del segundo parcial
            parcial2 = nota(alumno['Ordinario2'])
        elif alumno['Parcial2']:
            parcial2 = nota(alumno['Parcial2'])
        else: # No se ha presentado al segundo parcial ni a la repesca en el ordinario
            parcial2 = 0 
        if alumno['OrdinarioPracticas']: #Si el alumno se ha presentado al examen de repesca de prácticas tomamos esa nota como la nota de prácticas
            practicas = nota(alumno['OrdinarioPracticas'])
        elif alumno['Practicas']:
            practicas = nota(alumno['Practicas'])
        else:
            practicas = 0
        alumno['Final1'] = parcial1
        alumno['Final2'] = parcial2
        alumno['FinalPracticas'] = practicas
        alumno['NotaFinal'] = parcial1 * 0.3 + parcial2 * 0.3 + practicas * 0.4
        return alumno

    
    return list(map(nota_final, calificaciones))

def aprobados_suspensos(calificaciones):
    '''Función que recibe una lista de diccionarios con las calificaciones de cada alumno en un curso, y devuelve la lista de aprobados y suspensos en el curso.

    Parámetros:
        - calificaciones: Es una lista de diccionarios donde cada diccionario contiene los datos de un alumno (nombre, asistencia y notas de exámenes del curso).
    Devuelve:
        - aprobados: Es una lista con los nombres de los alumnos aprobados.
        - suspensos: Es una lista con los nombres de los alumnos suspensos.
    '''
    
    aprobados = []
    suspensos = []
    
    for alumno in calificaciones:
        
        if all([int(alumno['Asistencia'][:-1]) >= 75, alumno['Final1'] >= 4, alumno['Final2'] >=4, alumno['FinalPracticas'] >=4, alumno['NotaFinal'] >= 5]):
            aprobados.append(alumno['Apellidos'] + ', ' + alumno['Nombre'])
        else:
            suspensos.append(alumno['Apellidos'] + ', ' + alumno['Nombre'])
    return aprobados, suspensos


print(añadir_nota_final(calificaciones('calificaciones.csv')))
aprobados, suspensos = aprobados_suspensos(añadir_nota_final(calificaciones('calificaciones.csv')))
print('Lista de aprobados:', aprobados)
print('Lista de suspensos:', suspensos)
# Out:
# El fichero no existe.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 122
#     118             suspensos.append(alumno['Apellidos'] + ', ' + alumno['Nombre'])
#     119     return aprobados, suspensos
# --> 122 print(añadir_nota_final(calificaciones('calificaciones.csv')))
#     123 aprobados, suspensos = aprobados_suspensos(añadir_nota_final(calificaciones('calificaciones.csv')))
#     124 print('Lista de aprobados:', aprobados)
#
# Cell In[12], line 98, in añadir_nota_final(calificaciones)
#      94     alumno['NotaFinal'] = parcial1 * 0.3 + parcial2 * 0.3 + practicas * 0.4
#      95     return alumno
# ---> 98 return list(map(nota_final, calificaciones))
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# **Fuente:**
# [Aprende con Alf](https://aprendeconalf.es/)
